# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('/content/prevention_of_mother_to_child_transmission_by_country_clean.csv')

# %%
data.head()
# Out:
#        Country Received Antiretrovirals Needing antiretrovirals  \
# 0  Afghanistan                       20            200[100–500]
# 1      Albania                  No data                  Nodata
# 2      Algeria                      320            500[500–500]
# 3       Angola                     9600      25000[19000–32000]
# 4    Argentina                     1800         1800[1600–2000]
#
#   Percentage Recieved  Needing antiretrovirals_median  \
# 0            11[7–18]                           200.0
# 1              Nodata                             NaN
# 2           74[69–78]                           500.0
# 3           38[29–48]                         25000.0
# 4           95[85–95]                          1800.0
#
#    Needing antiretrovirals_min  Needing antiretrovirals_max  \
# 0                        100.0                        500.0
# 1                          NaN                          NaN
# 2                        500.0                        500.0
# ...

# %%
print(data)
# Out:
#                                 Country Received Antiretrovirals  \
# 0                           Afghanistan                       20
# 1                               Albania                  No data
# 2                               Algeria                      320
# 3                                Angola                     9600
# 4                             Argentina                     1800
# ..                                  ...                      ...
# 165  Venezuela (Bolivarian Republic of)                      410
# 166                            Viet Nam                     1900
# 167                               Yemen                       30
# 168                              Zambia                   56 500
# 169                            Zimbabwe                   59 600
#
#     Needing antiretrovirals Percentage Recieved  \
# 0              200[100–500]            11[7–18]
# 1                    Nodata              Nodata
# ...

# %%
data.isnull().sum()
# Out:
# Country                            0
# Received Antiretrovirals           0
# Needing antiretrovirals            0
# Percentage Recieved                4
# Needing antiretrovirals_median     0
# Needing antiretrovirals_min       70
# Needing antiretrovirals_max       70
# Percentage Recieved_median        78
# Percentage Recieved_min           78
# Percentage Recieved_max           78
# WHO Region                         0
# dtype: int64

# %%
data['Needing antiretrovirals_median'].fillna(data['Needing antiretrovirals_median'].median,inplace=True)

# %%
data.isnull().sum()
# Out:
# Country                            0
# Received Antiretrovirals           0
# Needing antiretrovirals            0
# Percentage Recieved                4
# Needing antiretrovirals_median     0
# Needing antiretrovirals_min       70
# Needing antiretrovirals_max       70
# Percentage Recieved_median        78
# Percentage Recieved_min           78
# Percentage Recieved_max           78
# WHO Region                         0
# dtype: int64

# %%
data['Needing antiretrovirals_min'].fillna(data['Needing antiretrovirals_min'].median,inplace=True)

# %%
data['Needing antiretrovirals_max'].fillna(data['Needing antiretrovirals_max'].median,inplace=True)

# %%
data['Percentage Recieved_min'].fillna(data['Percentage Recieved_min'].median,inplace=True)

# %%
data['Percentage Recieved_max'].fillna(data['Percentage Recieved_max'].median,inplace=True)

# %%
data['Percentage Recieved'].fillna(data['Percentage Recieved'].median,inplace=True)

# %%
data['Percentage Recieved_median'].fillna(data['Percentage Recieved_median'].median,inplace=True)

# %%
data.isnull().sum()
# Out:
# Country                           0
# Received Antiretrovirals          0
# Needing antiretrovirals           0
# Percentage Recieved               0
# Needing antiretrovirals_median    0
# Needing antiretrovirals_min       0
# Needing antiretrovirals_max       0
# Percentage Recieved_median        0
# Percentage Recieved_min           0
# Percentage Recieved_max           0
# WHO Region                        0
# dtype: int64

# %%
df=pd.DataFrame(data.data,column=data.Percentage_Recieved)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-28b4a36da973> in <module>
# ----> 1 df=pd.DataFrame(data.data,column=data.Percentage_Recieved)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'data'
